# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "Plenoi"
print("Hello "+ name +", are you ok? ")
# Out:
# Hello Plenoi, are you ok?

# %%
name = 'Jeompu '
print('Hello ' + name +', are you ok? ')
# Out:
# Hello Jeompu , are you ok?

# %%
name = 'Jeompu '
print('Hello ' + name +', เป็นไงบ้าง ')
# Out:
# Hello Jeompu , เป็นไงบ้าง

# %%
country = input("Where are you from = ")
# Out:
# Where are you from =  Thailand

# %%
print("I am form " + country)
# Out:
# I am form Thailand

# %%
age = int(input("What is your age = "))
# Out:
# What is your age =  20

# %%
print("I am " + age + " years old")
# Out:
# I am 20 years old

# %% [markdown]
# Ex. 1, How to fix this syntax error

# %%
age = int(input("What is your age = "))
tenyears_age = age + 10
print(tenyears_age)
# Out:
# What is your age =  20
# 30

# %%
tenyears_age = age + 10
print(tenyears_age)
# Out:
# 30

# %%
5+2 + 4*3
# Out:
# 19

# %%
5 + 2 - 4 * 3
# Out:
# -5

# %%
6/3
# Out:
# 2.0

# %%
11/3
# Out:
# 3.6666666666666665

# %%
11//3
# Out:
# 3

# %%
5%3
# Out:
# 2

# %%
5**2
# Out:
# 25

# %%
a = input("What is your A = ")
b = input("What is your B = ")
# Out:
# What is your A =  20
# What is your B =  30

# %%
c = a + b
print(c)
# Out:
# 2030

# %% [markdown]
# Ex. 3, How to fix this runtime error EX2 อยู่ข้างล่างค่า

# %%
a = int(input("What is your A = "))
b = int(input("What is your B = "))
c = a + b
print(c)
# Out:
# What is your A =  2
# What is your B =  3
# 5

# %%
greeting = "Hello"
name = ' World'
print(greeting + name)
# Out:
# Hello World

# %%
print("Hello 'World' PyThon")
# Out:
# Hello 'World' PyThon

# %%
print('Hello "World" PyThon')
# Out:
# Hello "World" PyThon

# %%
msg = "Hello " + "World!"
print(msg)
# Out:
# Hello World!

# %%
"ap" in "apple"
# Out:
# True

# %%
"Pa" in "Pattaraporn"
# Out:
# True

# %%
"Pah" in "Pattaraporn"
# Out:
# False

# %%
p = "Pa"
p in "Pattaraporn"
# Out:
# True

# %%
pi = 3.14
print(pi)
# Out:
# 3.14

# %% [markdown]
# Ex. 2, How to fix this syntax error

# %%
print("The pi is equal to" + pi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-d28082005652> in <module>
# ----> 1 print("The pi is equal to" + pi)
#
# TypeError: can only concatenate str (not "float") to str

# %%
print("The pi is equal to" +  str(pi))
# Out:
# The pi is equal to3.14

# %%
print("The pi is equal to" , pi)
# Out:
# The pi is equal to 3.14

# %%
name = "Plenoi"
age = 20
msg = f"Hello my name is {name} and my age is {age}"
print(msg)
# Out:
# Hello my name is Plenoi and my age is 20

# %%
a = "Pattaraporn"
b = "Kompang"
print(f"My name is {a} and my lastname is {b}")
# Out:
# My name is Pattaraporn and my lastname is Kompang

# %%
a = "Pattaraporn"
b = "Kompang"
print("My name is {a} and my lastname is {b}")
# Out:
# My name is {a} and my lastname is {b}

# %%
print("Hello my name is "+name+" and my age is "+str(age))
# Out:
# Hello my name is Plenoi and my age is 20

# %%
print("Hello my name is %s and my age is %.2f" % (name,age))
# Out:
# Hello my name is Plenoi and my age is 20.00

# %%
a = "Price"
b = 2000

print(a + " is " + str(b))
# Out:
# Price is 2000

# %%
a = "Price"
b = 2000

print("%s is %.2f" % (a,b)) # float
# Out:
# Price is 2000.00

# %%
print("Hello my name is {:} and my age is {:.2f}".format(name,age))
# Out:
# Hello my name is Plenoi and my age is 20.00

# %%
my_string = "Hello World"
my_string.upper()
# Out:
# 'HELLO WORLD'

# %%
a = "Jeompu"
a.upper()
# Out:
# 'JEOMPU'

# %%
a.lower()
# Out:
# 'jeompu'

# %%
a.find("P")
# Out:
# -1

# %%
a.find("p")
# Out:
# 4

# %%
my_string.index("World")
# Out:
# 6

# %%
a.capitalize()
# Out:
# 'Jeompu'

# %%
a.replace("o","")
# Out:
# 'Jempu'

# %%
a
# Out:
# 'Jeompu'

# %%
a = "Jeompu"
a2 = a.replace("o","")
a3 = a2.upper()

# %%
a3
# Out:
# 'JEMPU'

# %%
a = "Jeompu" + "\n"
a.rstrip()
# Out:
# 'Jeompu'

# %%
a
# Out:
# 'Jeompu\n'

# %%
a[2]
# Out:
# 'o'

# %%
a[3]
# Out:
# 'm'

# %%
a
# Out:
# 'Jeompu\n'

# %%
a.join("ABCD")
# Out:
# 'AJeompu\nBJeompu\nCJeompu\nD'

# %%
a = "Jeompu"

# %%
a.join("ABCD")
# Out:
# 'AJeompuBJeompuCJeompuD'

# %%
a = "Hello World"

# %%
" ".join("ABC")
# Out:
# 'A B C'

# %%
",".join("ABC")
# Out:
# 'A,B,C'

# %% [markdown]
# Ex 4, How to do this?

# %%
a = "Hello World"
a.split()
# Out:
# ['Hello', 'World']

# %%
",".join(a)
# Out:
# 'H,e,l,l,o, ,W,o,r,l,d'

# %%
L = [1,2,3,"Hello","World"]
L
# Out:
# [1, 2, 3, 'Hello', 'World']

# %%
L = [1,2,3, "a","b" ]
L
# Out:
# [1, 2, 3, 'a', 'b']

# %%
L.append(4)

# %%
L.append(5)

# %%
L = []

# %%
L.append(4)
L.append(5)

# %%
L
# Out:
# [4, 5]

# %%
L.remove(4)

# %%
L = []

# %%
L.append(4)
L.append(5)

# %%
L.append("เธอ")

# %%
L
# Out:
# [4, 5, 'เธอ']

# %%
L.remove("เธอ")

# %%
L
# Out:
# [4, 5]

# %%
L.pop(0)
# Out:
# 4

# %%
A=L.pop(0)

# %%
L = [ [1,2],[3,4],[5,6]]

# %%
L
# Out:
# [[1, 2], [3, 4], [5, 6]]

# %%
L.reverse()

# %%
L
# Out:
# [[5, 6], [3, 4], [1, 2]]

# %%
L=[3,4,1,5]
L
# Out:
# [3, 4, 1, 5]

# %%
L = ["กก","งง","ขข"]
L
# Out:
# ['กก', 'งง', 'ขข']

# %%
L.sort()
L
# Out:
# ['กก', 'ขข', 'งง']

# %%
"กก" in L
# Out:
# True

# %%
L = [1,2,3]

# %%
L = L+[4,5]

# %%
LL =L + [1 ,2]

# %%
LL
# Out:
# [1, 2, 3, 4, 5, 1, 2]

# %%
len(LL)
# Out:
# 7

# %% [markdown]
# Ex 5 How to use sort in descending order เรียงจากมากไปน้อย

# %%
L = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
L.sort(reverse=True)
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]
